# %% [markdown]
# <a href="https://colab.research.google.com/github/WafaSanaa/fullpack-ia-module-1/blob/main/Yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mount the Google Drive with the Colab Notebook**

# %%
#Mounting Google Drive

from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Set your Current Directory**

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %% [markdown]
# # **Created a Folder by the name Mining PPE Dataset**

# %%
# !mkdir MiningPPEProjectAS

# %% [markdown]
# # **Setting the Current Directory**

# %%
# %cd /content/drive/MyDrive/MiningPPEProjectAS
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS

# %% [markdown]
# # **Import the Required Libraries**

# %%
from IPython.display import Image

# %% [markdown]
# # **Clone the Github Repo**

# %%
# !git clone https://github.com/MuhammadMoin97/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 3878, done.
# remote: Total 3878 (delta 0), reused 0 (delta 0), pack-reused 3878 (from 1)
# Receiving objects: 100% (3878/3878), 1.82 MiB | 11.10 MiB/s, done.
# Resolving deltas: 100% (2691/2691), done.

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS

# %% [markdown]
# # **Setting the Current Directory**

# %%
# %cd /content/drive/MyDrive/MiningPPEProjectAS/ultralytics
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics

# %% [markdown]
# # **Install all the Dependencies**

# %%
# !pip install -e '.[dev]'
# Out:
# Obtaining file:///content/drive/MyDrive/MiningPPEProjectAS/ultralytics
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 49.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Moving to the Required Directory**

# %%
# %cd /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %% [markdown]
# # **Importing the Dataset from the RoboFlow**

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="CEUNDB2nxl8Ftgo3Cscc")
project = rf.workspace("weed-detection-ps1jf").project("weed-detection-sphza")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Weed-Detection-3 in yolov8:: 100%|██████████| 3610/3610 [00:27<00:00, 131.74it/s]

# %%
# !pip install --upgrade ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 17.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.0.3
#     Uninstalling ultralytics-8.0.3:
#       Successfully uninstalled ultralytics-8.0.3
# ...

# %%
from ultralytics import YOLO

# Chargement du modèle YOLOv8
model = YOLO("yolov8l.pt")  # Ce modèle sera téléchargé automatiquement s'il n'est pas local
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 170MB/s]

# %% [markdown]
# # **Training the Custom Model**

# %%
HOME = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect'

# %%
# %cd {HOME}
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect

# %%
# %cd {dataset.location}
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/Weed-Detection-3

# %%
# %cd {HOME}

# !python train.py model=yolov8l.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/train.py", line 10, in <module>
#     from ultralytics.yolo import v8
# ModuleNotFoundError: No module named 'ultralytics.yolo'

# %% [markdown]
# # **Checking the Files inside the Train Folder**

# %%
# !ls /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/Weed-Detection-3/train
# Out:
# images	labels

# %% [markdown]
# # **Printing the Confusion Matrix**

# %%
Image(filename = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train/images/C00020001_jpg.rf.c337207ba3cdf16414b84a4c738f1610.jpg')

# %% [markdown]
# # **Printing the Training and the Validation Loss**

# %%
Image(filename = r'/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train/images/C00020003_jpg.rf.f453cb25f44e6e623ec1f7e8a051aa22.jpg', width = 600)

# %% [markdown]
# # **Printing the Model Prediction on Validation Batch**

# %%
Image(filename = r'/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train/images/C00020054_jpg.rf.9e123d87b05e3be508eef62094a57f38.jpg', width =600)

# %% [markdown]
# # **Downloading the Weights From the Google Drive**

# %%
# %cd {HOME}
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect

# %%
# !gdown "https://drive.google.com/uc?id=1jG9vh3uYWbuLSiqgl1UozzlxY6jZbKh9&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jG9vh3uYWbuLSiqgl1UozzlxY6jZbKh9&confirm=t
# To: /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/best.pt
# 100% 52.0M/52.0M [00:01<00:00, 38.8MB/s]

# %% [markdown]
# # **Validate Custom Model**

# %%
# !pwd
# Out:
# /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect

# %%
# !python val.py model='best.pt' data={dataset.location}/data.yaml
# Out:
# python3: can't open file '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/val.py': [Errno 2] No such file or directory

# %% [markdown]
# # **Inference with Custom Model**

# %% [markdown]
# # Testing on Images

# %%
# !python predict.py model='best.pt' source='/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/Weed-Detection-3/test/images'
# Out:
# python3: can't open file '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/predict.py': [Errno 2] No such file or directory

# %% [markdown]
# # Display Output Images

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train2/*.jpg')[23:30]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %% [markdown]
# # Demo Video 1

# %%
# !gdown "https://drive.google.com/uc?id=1crFwrpMF1OlaJ0ZCZjBNRo9llLEVR8VQ&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1crFwrpMF1OlaJ0ZCZjBNRo9llLEVR8VQ&confirm=t
# To: /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/demo.mp4
# 100% 42.9M/42.9M [00:00<00:00, 251MB/s]

# %%
# !python predict.py model='best.pt' source='demo.mp4'
# Out:
# python3: can't open file '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/predict.py': [Errno 2] No such file or directory

# %% [markdown]
# # Display the Demo Video

# %%
# !rm "/content/result_compressed.mp4"
# Out:
# rm: cannot remove '/content/result_compressed.mp4': No such file or directory

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train3/demo.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-d166196f2995> in <cell line: 0>()
#      12
#      13 # Show video
# ---> 14 mp4 = open(compressed_path,'rb').read()
#      15 data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
#      16 HTML("""
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/result_compressed.mp4'

# %% [markdown]
# # Demo Video 2

# %%
# !gdown "https://drive.google.com/uc?id=1cTIBNQ1R_7JAOURVv9cJ6P935ym_IkZ0&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1cTIBNQ1R_7JAOURVv9cJ6P935ym_IkZ0&confirm=t
# To: /content/drive/MyDrive/MiningPPEProjectAS/ultralytics/ultralytics/yolo/v8/detect/demo3.mp4
# 100% 20.3M/20.3M [00:00<00:00, 50.5MB/s]

# %%
# !python predict.py model='best.pt' source='demo3.mp4'
# Out:
# 2025-05-25 19:38:51.198844: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748201931.221884   14013 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748201931.228953   14013 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-25 19:38:51.252810: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # Display the Demo Video

# %%
# !rm "/content/result_compressed.mp4"
# Out:
# rm: cannot remove '/content/result_compressed.mp4': No such file or directory

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/drive/MyDrive/MiningPPEProjectAS/ultralytics/runs/detect/train4/demo3.mp4'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-728e4fe5df3f> in <cell line: 0>()
#      12
#      13 # Show video
# ---> 14 mp4 = open(compressed_path,'rb').read()
#      15 data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
#      16 HTML("""
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/result_compressed.mp4'
